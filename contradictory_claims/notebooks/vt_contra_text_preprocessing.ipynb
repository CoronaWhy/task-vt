# %%
import os
import re
import ast
import numpy as np
import pandas as pd
import glob
import json

import tarfile

from datetime import datetime

from pandas.io.json import json_normalize

from zipfile import ZipFile

from sklearn.metrics.pairwise import cosine_similarity

from numba import jit

# %%
"""
Preprocessing Cord-19 text files

Goal: Filter text and vector files containing publications (1 sentence per row) to publications 
relevant to Covid-19 and specified columns.  Merge into a single file for extraction of sentences/vectors
belonging to specified papers/sections.

Steps:
    1. Filter metadata.csv (from Kaggle Cord-19 dataset) to paper cord_uids for papers where:
        -Title or Abstract contains 1 or more Covid-19 synonyms.
        -Publication date is after 2019-10-01.
        This has been moved to notebook covid_vt_contra_metadata_filtering.ipynb
        
    2.  Load all full text files (json format) as pandas dataframes and truncate them to:
            -Rows containing cord_uids from step 1
            -Columns cord_uid, sentence, and section

        Write truncated text dataframe to json.
    
    5.  Filter to title, abstract and discussion sections
    
    6.  Filter out noisy sentences (with <3 words, etc.)
"""
# Out:
# '\nPreprocessing Cord-19 text files\n\nGoal: Filter text and vector files containing publications (1 sentence per row) to publications \nrelevant to Covid-19 and specified columns.  Merge into a single file for extraction of sentences/vectors\nbelonging to specified papers/sections.\n\nSteps:\n    1. Filter metadata.csv (from Kaggle Cord-19 dataset) to paper cord_uids for papers where:\n        -Title or Abstract contains 1 or more Covid-19 synonyms.\n        -Publication date is after 2019-10-01.\n        This has been moved to notebook covid_vt_contra_metadata_filtering.ipynb\n        \n    2.  Load all full text files (parquet format) as pandas dataframes and truncate them to:\n            -Rows containing cord_uids from step 1\n            -Columns cord_uid, sentence_id, sentence, and section\n\n        Write truncated text dataframes to csv files.\n\n    3.  Merge truncated text dataframes and extract list of sentence_ids for truncating vector files.\n    \n    4.  Load all vector files (parquet format) as pandas dataframes and truncate them to:\n            -Rows containing sentence_ids from step 3.\n        \n        Write truncated vector dataframes to csv files.\n    \n    5.  Merge truncated vector dataframes and join with merged truncated text files (merged_text_vector_df).\n    \n    6.  Write merged, truncated vector and text dataframe to csv file.\n'

# %%
json_text_file_dir = 'C:\\Users\\SuresMal\\Documents\\Coronawhy\\data\\cord19\\2020-08-15\\document_parses.tar.gz'
json_temp_path = 'C:\\Users\\SuresMal\\Documents\\Coronawhy\\data\\cord19\\extracted\\'
processed_text_df_outfile_path = 'C:\\Users\\SuresMal\\Documents\\Coronawhy\\data\\cord19\\2020-08-15\\processed\\cord_titles_abstracts_conclusions_150820.csv'

# %%
covid19_metadata = pd.read_csv("C:\\Users\\SuresMal\\Documents\\Coronawhy\\data\\cord19\\2020-08-15\\processed\\covid19_date_filt_metadata_150820.csv")
pdf_filenames = list(covid19_metadata.pdf_json_files)
pmc_filenames = list(covid19_metadata.pmc_json_files)
# Out:
# C:\Users\SuresMal\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5,6,7,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
covid19_dict = {}
replace_dict = {'â€œ' : '“',
                'â€' : '”',
                'â€™' : '’',
                'â€˜' : '‘',
                'â€”' : '–',
                'â€“' : '—',
                'â€¢' : '-',
                'â€¦' : '…'}

if '.zip' in json_text_file_dir:
    zipobj = ZipFile(json_text_file_dir, 'r')
    list_of_filenames = zipobj.namelist()
elif 'tar.gz' in json_text_file_dir:
    tarf = tarfile.open(json_text_file_dir, 'r:gz')
    list_of_filenames = tarf.getnames()
else:
    raise Exception("Incorrcet file extension. Must be '.zip' or '.tar.gz'")
print('Number of files to iterate over:',len(list_of_filenames))
k = 0
# TODO: Parallelize the code below
for iter_num, filename in enumerate(list_of_filenames):
    # Check filename ends with json and file exists in filtered list of cord papers
    if (filename in pdf_filenames) or (filename in pmc_filenames):
        if '.zip' in json_text_file_dir:
            zipobj.extract(filename, json_temp_path)
        elif 'tar.gz' in json_text_file_dir:
            tarf.extract(tarf.getmembers()[iter_num], json_temp_path)
        with open(json_temp_path + filename, 'r', encoding='utf8') as f:
            # Read each line in the file separately, remove tabs, spaces and newlines
            # and concatenate all lines together for further parsing
            json_str = "".join([" ".join(line.split()) for line in f])
            # Parse the json string into the json dictionary format
            json_dict = json.loads(json_str, encoding='utf8')
            # Convert the json dictionary object to a pandas dataframe
            paper_df = json_normalize(json_dict)
            # In the covid19 metadata dataframe,
            # filter to the row representing the current json file being processed
            # and extract the cord_uid
            check_file_name = ((filename == covid19_metadata.pdf_json_files)
                               | (filename == covid19_metadata.pmc_json_files))  # noqa: W503
            cord_uid = list(covid19_metadata.loc[check_file_name, 'cord_uid'])[0]
            # If an abstract section exists, extract the text
            try:
                text = paper_df['abstract'][0][0]['text']
                section = paper_df['abstract'][0][0]['section']
                # Replace characters with their readable format
                for key, v in replace_dict.items():
                    text = text.replace(key, v)
                    section = section.replace(key, v)
                covid19_dict[k] = {'cord_uid': cord_uid,
                                   'sentence': text,
                                   'section': section}
                k = k + 1
            # If an abstract section does not exist, skip
            except KeyError:
                pass
            except IndexError:
                pass

            for temp_dict in paper_df['body_text'][0]:
                text = temp_dict['text']
                section = temp_dict['section']
                # Replace characters with their readable format
                for key, v in replace_dict.items():
                    text = text.replace(key, v)
                    section = section.replace(key, v)
                covid19_dict[k] = {'cord_uid': cord_uid,
                                   'sentence': text,
                                   'section': section}
                k = k + 1

    if iter_num%100==0:
        print('Number of files read:', iter_num+1)
# Out:
# Number of files to iterate over: 165488
# Number of files read: 1
# Number of files read: 101
# Number of files read: 201
# Number of files read: 301
# Number of files read: 401
# Number of files read: 501
# Number of files read: 601
# Number of files read: 701
# Number of files read: 801
# Number of files read: 901
# Number of files read: 1001
# Number of files read: 1101
# Number of files read: 1201
# Number of files read: 1301
# Number of files read: 1401
# Number of files read: 1501
# Number of files read: 1601
# Number of files read: 1701
# Number of files read: 1801
# Number of files read: 1901
# Number of files read: 2001
# Number of files read: 2101
# Number of files read: 2201
# Number of files read: 2301
# Number of files read: 2401
# Number of files read: 2501
# Number of files read: 2601
# Number of files read: 2701
# Number of files read: 2801
# Number of files read: 2901
# Number of files read: 3001
# Number of files read: 3101
# Number of files read: 3201
# Number of files read: 3301
# Number of files read: 3401
# Number of files read: 3501
# Number of files read: 3601
# Number of files read: 3701
# Number of files read: 3801
# Number of files read: 3901
# Number of files read: 4001
# Number of files read: 4101
# Number of files read: 4201
# Number of files read: 4301
# Number of files read: 4401
# Number of files read: 4501
# Number of files read: 4601
# Number of files read: 4701
# Number of files read: 4801
# Number of files read: 4901
# Number of files read: 5001
# Number of files read: 5101
# Number of files read: 5201
# Number of files read: 5301
# Number of files read: 5401
# Number of files read: 5501
# Number of files read: 5601
# Number of files read: 5701
# Number of files read: 5801
# Number of files read: 5901
# Number of files read: 6001
# Number of files read: 6101
# Number of files read: 6201
# Number of files read: 6301
# Number of files read: 6401
# Number of files read: 6501
# Number of files read: 6601
# Number of files read: 6701
# Number of files read: 6801
# Number of files read: 6901
# Number of files read: 7001
# Number of files read: 7101
# Number of files read: 7201
# Number of files read: 7301
# Number of files read: 7401
# Number of files read: 7501
# Number of files read: 7601
# Number of files read: 7701
# Number of files read: 7801
# Number of files read: 7901
# Number of files read: 8001
# Number of files read: 8101
# Number of files read: 8201
# Number of files read: 8301
# Number of files read: 8401
# Number of files read: 8501
# Number of files read: 8601
# Number of files read: 8701
# Number of files read: 8801
# Number of files read: 8901
# C:\Users\SuresMal\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# Number of files read: 9001
# Number of files read: 9101
# Number of files read: 9201
# Number of files read: 9301
# Number of files read: 9401
# Number of files read: 9501
# Number of files read: 9601
# Number of files read: 9701
# Number of files read: 9801
# Number of files read: 9901
# Number of files read: 10001
# Number of files read: 10101
# Number of files read: 10201
# Number of files read: 10301
# Number of files read: 10401
# Number of files read: 10501
# Number of files read: 10601
# Number of files read: 10701
# Number of files read: 10801
# Number of files read: 10901
# Number of files read: 11001
# Number of files read: 11101
# Number of files read: 11201
# Number of files read: 11301
# Number of files read: 11401
# Number of files read: 11501
# Number of files read: 11601
# Number of files read: 11701
# Number of files read: 11801
# Number of files read: 11901
# Number of files read: 12001
# Number of files read: 12101
# Number of files read: 12201
# Number of files read: 12301
# Number of files read: 12401
# Number of files read: 12501
# Number of files read: 12601
# Number of files read: 12701
# Number of files read: 12801
# Number of files read: 12901
# Number of files read: 13001
# Number of files read: 13101
# Number of files read: 13201
# Number of files read: 13301
# Number of files read: 13401
# Number of files read: 13501
# Number of files read: 13601
# Number of files read: 13701
# Number of files read: 13801
# Number of files read: 13901
# Number of files read: 14001
# Number of files read: 14101
# Number of files read: 14201
# Number of files read: 14301
# Number of files read: 14401
# Number of files read: 14501
# Number of files read: 14601
# Number of files read: 14701
# Number of files read: 14801
# Number of files read: 14901
# Number of files read: 15001
# Number of files read: 15101
# Number of files read: 15201
# Number of files read: 15301
# Number of files read: 15401
# Number of files read: 15501
# Number of files read: 15601
# Number of files read: 15701
# Number of files read: 15801
# Number of files read: 15901
# Number of files read: 16001
# Number of files read: 16101
# Number of files read: 16201
# Number of files read: 16301
# Number of files read: 16401
# Number of files read: 16501
# Number of files read: 16601
# Number of files read: 16701
# Number of files read: 16801
# Number of files read: 16901
# Number of files read: 17001
# Number of files read: 17101
# Number of files read: 17201
# Number of files read: 17301
# Number of files read: 17401
# Number of files read: 17501
# Number of files read: 17601
# Number of files read: 17701
# Number of files read: 17801
# Number of files read: 17901
# Number of files read: 18001
# Number of files read: 18101
# Number of files read: 18201
# Number of files read: 18301
# Number of files read: 18401
# Number of files read: 18501
# Number of files read: 18601
# Number of files read: 18701
# Number of files read: 18801
# Number of files read: 18901
# Number of files read: 19001
# Number of files read: 19101
# Number of files read: 19201
# Number of files read: 19301
# Number of files read: 19401
# Number of files read: 19501
# Number of files read: 19601
# Number of files read: 19701
# Number of files read: 19801
# Number of files read: 19901
# Number of files read: 20001
# Number of files read: 20101
# Number of files read: 20201
# Number of files read: 20301
# Number of files read: 20401
# Number of files read: 20501
# Number of files read: 20601
# Number of files read: 20701
# Number of files read: 20801
# Number of files read: 20901
# Number of files read: 21001
# Number of files read: 21101
# Number of files read: 21201
# Number of files read: 21301
# Number of files read: 21401
# Number of files read: 21501
# Number of files read: 21601
# Number of files read: 21701
# Number of files read: 21801
# Number of files read: 21901
# Number of files read: 22001
# Number of files read: 22101
# Number of files read: 22201
# Number of files read: 22301
# Number of files read: 22401
# Number of files read: 22501
# Number of files read: 22601
# Number of files read: 22701
# Number of files read: 22801
# Number of files read: 22901
# Number of files read: 23001
# Number of files read: 23101
# Number of files read: 23201
# Number of files read: 23301
# Number of files read: 23401
# Number of files read: 23501
# Number of files read: 23601
# Number of files read: 23701
# Number of files read: 23801
# Number of files read: 23901
# Number of files read: 24001
# Number of files read: 24101
# Number of files read: 24201
# Number of files read: 24301
# Number of files read: 24401
# Number of files read: 24501
# Number of files read: 24601
# Number of files read: 24701
# Number of files read: 24801
# Number of files read: 24901
# Number of files read: 25001
# Number of files read: 25101
# Number of files read: 25201
# Number of files read: 25301
# Number of files read: 25401
# Number of files read: 25501
# Number of files read: 25601
# Number of files read: 25701
# Number of files read: 25801
# Number of files read: 25901
# Number of files read: 26001
# Number of files read: 26101
# Number of files read: 26201
# Number of files read: 26301
# Number of files read: 26401
# Number of files read: 26501
# Number of files read: 26601
# Number of files read: 26701
# Number of files read: 26801
# Number of files read: 26901
# Number of files read: 27001
# Number of files read: 27101
# Number of files read: 27201
# Number of files read: 27301
# Number of files read: 27401
# Number of files read: 27501
# Number of files read: 27601
# Number of files read: 27701
# Number of files read: 27801
# Number of files read: 27901
# Number of files read: 28001
# Number of files read: 28101
# Number of files read: 28201
# Number of files read: 28301
# Number of files read: 28401
# Number of files read: 28501
# Number of files read: 28601
# Number of files read: 28701
# Number of files read: 28801
# Number of files read: 28901
# Number of files read: 29001
# Number of files read: 29101
# Number of files read: 29201
# Number of files read: 29301
# Number of files read: 29401
# Number of files read: 29501
# Number of files read: 29601
# Number of files read: 29701
# Number of files read: 29801
# Number of files read: 29901
# Number of files read: 30001
# Number of files read: 30101
# Number of files read: 30201
# Number of files read: 30301
# Number of files read: 30401
# Number of files read: 30501
# Number of files read: 30601
# Number of files read: 30701
# Number of files read: 30801
# Number of files read: 30901
# Number of files read: 31001
# Number of files read: 31101
# Number of files read: 31201
# Number of files read: 31301
# Number of files read: 31401
# Number of files read: 31501
# Number of files read: 31601
# Number of files read: 31701
# Number of files read: 31801
# Number of files read: 31901
# Number of files read: 32001
# Number of files read: 32101
# Number of files read: 32201
# Number of files read: 32301
# Number of files read: 32401
# Number of files read: 32501
# Number of files read: 32601
# Number of files read: 32701
# Number of files read: 32801
# Number of files read: 32901
# Number of files read: 33001
# Number of files read: 33101
# Number of files read: 33201
# Number of files read: 33301
# Number of files read: 33401
# Number of files read: 33501
# Number of files read: 33601
# Number of files read: 33701
# Number of files read: 33801
# Number of files read: 33901
# Number of files read: 34001
# Number of files read: 34101
# Number of files read: 34201
# Number of files read: 34301
# Number of files read: 34401
# Number of files read: 34501
# Number of files read: 34601
# Number of files read: 34701
# Number of files read: 34801
# Number of files read: 34901
# Number of files read: 35001
# Number of files read: 35101
# Number of files read: 35201
# Number of files read: 35301
# Number of files read: 35401
# Number of files read: 35501
# Number of files read: 35601
# Number of files read: 35701
# Number of files read: 35801
# Number of files read: 35901
# Number of files read: 36001
# Number of files read: 36101
# Number of files read: 36201
# Number of files read: 36301
# Number of files read: 36401
# Number of files read: 36501
# Number of files read: 36601
# Number of files read: 36701
# Number of files read: 36801
# Number of files read: 36901
# Number of files read: 37001
# Number of files read: 37101
# Number of files read: 37201
# Number of files read: 37301
# Number of files read: 37401
# Number of files read: 37501
# Number of files read: 37601
# Number of files read: 37701
# Number of files read: 37801
# Number of files read: 37901
# Number of files read: 38001
# Number of files read: 38101
# Number of files read: 38201
# Number of files read: 38301
# Number of files read: 38401
# Number of files read: 38501
# Number of files read: 38601
# Number of files read: 38701
# Number of files read: 38801
# Number of files read: 38901
# Number of files read: 39001
# Number of files read: 39101
# Number of files read: 39201
# Number of files read: 39301
# Number of files read: 39401
# Number of files read: 39501
# Number of files read: 39601
# Number of files read: 39701
# Number of files read: 39801
# Number of files read: 39901
# Number of files read: 40001
# Number of files read: 40101
# Number of files read: 40201
# Number of files read: 40301
# Number of files read: 40401
# Number of files read: 40501
# Number of files read: 40601
# Number of files read: 40701
# Number of files read: 40801
# Number of files read: 40901
# Number of files read: 41001
# Number of files read: 41101
# Number of files read: 41201
# Number of files read: 41301
# Number of files read: 41401
# Number of files read: 41501
# Number of files read: 41601
# Number of files read: 41701
# Number of files read: 41801
# Number of files read: 41901
# Number of files read: 42001
# Number of files read: 42101
# Number of files read: 42201
# Number of files read: 42301
# Number of files read: 42401
# Number of files read: 42501
# Number of files read: 42601
# Number of files read: 42701
# Number of files read: 42801
# Number of files read: 42901
# Number of files read: 43001
# Number of files read: 43101
# Number of files read: 43201
# Number of files read: 43301
# Number of files read: 43401
# Number of files read: 43501
# Number of files read: 43601
# Number of files read: 43701
# Number of files read: 43801
# Number of files read: 43901
# Number of files read: 44001
# Number of files read: 44101
# Number of files read: 44201
# Number of files read: 44301
# Number of files read: 44401
# Number of files read: 44501
# Number of files read: 44601
# Number of files read: 44701
# Number of files read: 44801
# Number of files read: 44901
# Number of files read: 45001
# Number of files read: 45101
# Number of files read: 45201
# Number of files read: 45301
# Number of files read: 45401
# Number of files read: 45501
# Number of files read: 45601
# Number of files read: 45701
# Number of files read: 45801
# Number of files read: 45901
# Number of files read: 46001
# Number of files read: 46101
# Number of files read: 46201
# Number of files read: 46301
# Number of files read: 46401
# Number of files read: 46501
# Number of files read: 46601
# Number of files read: 46701
# Number of files read: 46801
# Number of files read: 46901
# Number of files read: 47001
# Number of files read: 47101
# Number of files read: 47201
# Number of files read: 47301
# Number of files read: 47401
# Number of files read: 47501
# Number of files read: 47601
# Number of files read: 47701
# Number of files read: 47801
# Number of files read: 47901
# Number of files read: 48001
# Number of files read: 48101
# Number of files read: 48201
# Number of files read: 48301
# Number of files read: 48401
# Number of files read: 48501
# Number of files read: 48601
# Number of files read: 48701
# Number of files read: 48801
# Number of files read: 48901
# Number of files read: 49001
# Number of files read: 49101
# Number of files read: 49201
# Number of files read: 49301
# Number of files read: 49401
# Number of files read: 49501
# Number of files read: 49601
# Number of files read: 49701
# Number of files read: 49801
# Number of files read: 49901
# Number of files read: 50001
# Number of files read: 50101
# Number of files read: 50201
# Number of files read: 50301
# Number of files read: 50401
# Number of files read: 50501
# Number of files read: 50601
# Number of files read: 50701
# Number of files read: 50801
# Number of files read: 50901
# Number of files read: 51001
# Number of files read: 51101
# Number of files read: 51201
# Number of files read: 51301
# Number of files read: 51401
# Number of files read: 51501
# Number of files read: 51601
# Number of files read: 51701
# Number of files read: 51801
# Number of files read: 51901
# Number of files read: 52001
# Number of files read: 52101
# Number of files read: 52201
# Number of files read: 52301
# Number of files read: 52401
# Number of files read: 52501
# Number of files read: 52601
# Number of files read: 52701
# Number of files read: 52801
# Number of files read: 52901
# Number of files read: 53001
# Number of files read: 53101
# Number of files read: 53201
# Number of files read: 53301
# Number of files read: 53401
# Number of files read: 53501
# Number of files read: 53601
# Number of files read: 53701
# Number of files read: 53801
# Number of files read: 53901
# Number of files read: 54001
# Number of files read: 54101
# Number of files read: 54201
# Number of files read: 54301
# Number of files read: 54401
# Number of files read: 54501
# Number of files read: 54601
# Number of files read: 54701
# Number of files read: 54801
# Number of files read: 54901
# Number of files read: 55001
# Number of files read: 55101
# Number of files read: 55201
# Number of files read: 55301
# Number of files read: 55401
# Number of files read: 55501
# Number of files read: 55601
# Number of files read: 55701
# Number of files read: 55801
# Number of files read: 55901
# Number of files read: 56001
# Number of files read: 56101
# Number of files read: 56201
# Number of files read: 56301
# Number of files read: 56401
# Number of files read: 56501
# Number of files read: 56601
# Number of files read: 56701
# Number of files read: 56801
# Number of files read: 56901
# Number of files read: 57001
# Number of files read: 57101
# Number of files read: 57201
# Number of files read: 57301
# Number of files read: 57401
# Number of files read: 57501
# Number of files read: 57601
# Number of files read: 57701
# Number of files read: 57801
# Number of files read: 57901
# Number of files read: 58001
# Number of files read: 58101
# Number of files read: 58201
# Number of files read: 58301
# Number of files read: 58401
# Number of files read: 58501
# Number of files read: 58601
# Number of files read: 58701
# Number of files read: 58801
# Number of files read: 58901
# Number of files read: 59001
# Number of files read: 59101
# Number of files read: 59201
# Number of files read: 59301
# Number of files read: 59401
# Number of files read: 59501
# Number of files read: 59601
# Number of files read: 59701
# Number of files read: 59801
# Number of files read: 59901
# Number of files read: 60001
# Number of files read: 60101
# Number of files read: 60201
# Number of files read: 60301
# Number of files read: 60401
# Number of files read: 60501
# Number of files read: 60601
# Number of files read: 60701
# Number of files read: 60801
# Number of files read: 60901
# Number of files read: 61001
# Number of files read: 61101
# Number of files read: 61201
# Number of files read: 61301
# Number of files read: 61401
# Number of files read: 61501
# Number of files read: 61601
# Number of files read: 61701
# Number of files read: 61801
# Number of files read: 61901
# Number of files read: 62001
# Number of files read: 62101
# Number of files read: 62201
# Number of files read: 62301
# Number of files read: 62401
# Number of files read: 62501
# Number of files read: 62601
# Number of files read: 62701
# Number of files read: 62801
# Number of files read: 62901
# Number of files read: 63001
# Number of files read: 63101
# Number of files read: 63201
# Number of files read: 63301
# Number of files read: 63401
# Number of files read: 63501
# Number of files read: 63601
# Number of files read: 63701
# Number of files read: 63801
# Number of files read: 63901
# Number of files read: 64001
# Number of files read: 64101
# Number of files read: 64201
# Number of files read: 64301
# Number of files read: 64401
# Number of files read: 64501
# Number of files read: 64601
# Number of files read: 64701
# Number of files read: 64801
# Number of files read: 64901
# Number of files read: 65001
# Number of files read: 65101
# Number of files read: 65201
# Number of files read: 65301
# Number of files read: 65401
# Number of files read: 65501
# Number of files read: 65601
# Number of files read: 65701
# Number of files read: 65801
# Number of files read: 65901
# Number of files read: 66001
# Number of files read: 66101
# Number of files read: 66201
# Number of files read: 66301
# Number of files read: 66401
# Number of files read: 66501
# Number of files read: 66601
# Number of files read: 66701
# Number of files read: 66801
# Number of files read: 66901
# Number of files read: 67001
# Number of files read: 67101
# Number of files read: 67201
# Number of files read: 67301
# Number of files read: 67401
# Number of files read: 67501
# Number of files read: 67601
# Number of files read: 67701
# Number of files read: 67801
# Number of files read: 67901
# Number of files read: 68001
# Number of files read: 68101
# Number of files read: 68201
# Number of files read: 68301
# Number of files read: 68401
# Number of files read: 68501
# Number of files read: 68601
# Number of files read: 68701
# Number of files read: 68801
# Number of files read: 68901
# Number of files read: 69001
# Number of files read: 69101
# Number of files read: 69201
# Number of files read: 69301
# Number of files read: 69401
# Number of files read: 69501
# Number of files read: 69601
# Number of files read: 69701
# Number of files read: 69801
# Number of files read: 69901
# Number of files read: 70001
# Number of files read: 70101
# Number of files read: 70201
# Number of files read: 70301
# Number of files read: 70401
# Number of files read: 70501
# Number of files read: 70601
# Number of files read: 70701
# Number of files read: 70801
# Number of files read: 70901
# Number of files read: 71001
# Number of files read: 71101
# Number of files read: 71201
# Number of files read: 71301
# Number of files read: 71401
# Number of files read: 71501
# Number of files read: 71601
# Number of files read: 71701
# Number of files read: 71801
# Number of files read: 71901
# Number of files read: 72001
# Number of files read: 72101
# Number of files read: 72201
# Number of files read: 72301
# Number of files read: 72401
# Number of files read: 72501
# Number of files read: 72601
# Number of files read: 72701
# Number of files read: 72801
# Number of files read: 72901
# Number of files read: 73001
# Number of files read: 73101
# Number of files read: 73201
# Number of files read: 73301
# Number of files read: 73401
# Number of files read: 73501
# Number of files read: 73601
# Number of files read: 73701
# Number of files read: 73801
# Number of files read: 73901
# Number of files read: 74001
# Number of files read: 74101
# Number of files read: 74201
# Number of files read: 74301
# Number of files read: 74401
# Number of files read: 74501
# Number of files read: 74601
# Number of files read: 74701
# Number of files read: 74801
# Number of files read: 74901
# Number of files read: 75001
# Number of files read: 75101
# Number of files read: 75201
# Number of files read: 75301
# Number of files read: 75401
# Number of files read: 75501
# Number of files read: 75601
# Number of files read: 75701
# Number of files read: 75801
# Number of files read: 75901
# Number of files read: 76001
# Number of files read: 76101
# Number of files read: 76201
# Number of files read: 76301
# Number of files read: 76401
# Number of files read: 76501
# Number of files read: 76601
# Number of files read: 76701
# Number of files read: 76801
# Number of files read: 76901
# Number of files read: 77001
# Number of files read: 77101
# Number of files read: 77201
# Number of files read: 77301
# Number of files read: 77401
# Number of files read: 77501
# Number of files read: 77601
# Number of files read: 77701
# Number of files read: 77801
# Number of files read: 77901
# Number of files read: 78001
# Number of files read: 78101
# Number of files read: 78201
# Number of files read: 78301
# Number of files read: 78401
# Number of files read: 78501
# Number of files read: 78601
# Number of files read: 78701
# Number of files read: 78801
# Number of files read: 78901
# Number of files read: 79001
# Number of files read: 79101
# Number of files read: 79201
# Number of files read: 79301
# Number of files read: 79401
# Number of files read: 79501
# Number of files read: 79601
# Number of files read: 79701
# Number of files read: 79801
# Number of files read: 79901
# Number of files read: 80001
# Number of files read: 80101
# Number of files read: 80201
# Number of files read: 80301
# Number of files read: 80401
# Number of files read: 80501
# Number of files read: 80601
# Number of files read: 80701
# Number of files read: 80801
# Number of files read: 80901
# Number of files read: 81001
# Number of files read: 81101
# Number of files read: 81201
# Number of files read: 81301
# Number of files read: 81401
# Number of files read: 81501
# Number of files read: 81601
# Number of files read: 81701
# Number of files read: 81801
# Number of files read: 81901
# Number of files read: 82001
# Number of files read: 82101
# Number of files read: 82201
# Number of files read: 82301
# Number of files read: 82401
# Number of files read: 82501
# Number of files read: 82601
# Number of files read: 82701
# Number of files read: 82801
# Number of files read: 82901
# Number of files read: 83001
# Number of files read: 83101
# Number of files read: 83201
# Number of files read: 83301
# Number of files read: 83401
# Number of files read: 83501
# Number of files read: 83601
# Number of files read: 83701
# Number of files read: 83801
# Number of files read: 83901
# Number of files read: 84001
# Number of files read: 84101
# Number of files read: 84201
# Number of files read: 84301
# Number of files read: 84401
# Number of files read: 84501
# Number of files read: 84601
# Number of files read: 84701
# Number of files read: 84801
# Number of files read: 84901
# Number of files read: 85001
# Number of files read: 85101
# Number of files read: 85201
# Number of files read: 85301
# Number of files read: 85401
# Number of files read: 85501
# Number of files read: 85601
# Number of files read: 85701
# Number of files read: 85801
# Number of files read: 85901
# Number of files read: 86001
# Number of files read: 86101
# Number of files read: 86201
# Number of files read: 86301
# Number of files read: 86401
# Number of files read: 86501
# Number of files read: 86601
# Number of files read: 86701
# Number of files read: 86801
# Number of files read: 86901
# Number of files read: 87001
# Number of files read: 87101
# Number of files read: 87201
# Number of files read: 87301
# Number of files read: 87401
# Number of files read: 87501
# Number of files read: 87601
# Number of files read: 87701
# Number of files read: 87801
# Number of files read: 87901
# Number of files read: 88001
# Number of files read: 88101
# Number of files read: 88201
# Number of files read: 88301
# Number of files read: 88401
# Number of files read: 88501
# Number of files read: 88601
# Number of files read: 88701
# Number of files read: 88801
# Number of files read: 88901
# Number of files read: 89001
# Number of files read: 89101
# Number of files read: 89201
# Number of files read: 89301
# Number of files read: 89401
# Number of files read: 89501
# Number of files read: 89601
# Number of files read: 89701
# Number of files read: 89801
# Number of files read: 89901
# Number of files read: 90001
# Number of files read: 90101
# Number of files read: 90201
# Number of files read: 90301
# Number of files read: 90401
# Number of files read: 90501
# Number of files read: 90601
# Number of files read: 90701
# Number of files read: 90801
# Number of files read: 90901
# Number of files read: 91001
# Number of files read: 91101
# Number of files read: 91201
# Number of files read: 91301
# Number of files read: 91401
# Number of files read: 91501
# Number of files read: 91601
# Number of files read: 91701
# Number of files read: 91801
# Number of files read: 91901
# Number of files read: 92001
# Number of files read: 92101
# Number of files read: 92201
# Number of files read: 92301
# Number of files read: 92401
# Number of files read: 92501
# Number of files read: 92601
# Number of files read: 92701
# Number of files read: 92801
# Number of files read: 92901
# Number of files read: 93001
# Number of files read: 93101
# Number of files read: 93201
# Number of files read: 93301
# Number of files read: 93401
# Number of files read: 93501
# Number of files read: 93601
# Number of files read: 93701
# Number of files read: 93801
# Number of files read: 93901
# Number of files read: 94001
# Number of files read: 94101
# Number of files read: 94201
# Number of files read: 94301
# Number of files read: 94401
# Number of files read: 94501
# Number of files read: 94601
# Number of files read: 94701
# Number of files read: 94801
# Number of files read: 94901
# Number of files read: 95001
# Number of files read: 95101
# Number of files read: 95201
# Number of files read: 95301
# Number of files read: 95401
# Number of files read: 95501
# Number of files read: 95601
# Number of files read: 95701
# Number of files read: 95801
# Number of files read: 95901
# Number of files read: 96001
# Number of files read: 96101
# Number of files read: 96201
# Number of files read: 96301
# Number of files read: 96401
# Number of files read: 96501
# Number of files read: 96601
# Number of files read: 96701
# Number of files read: 96801
# Number of files read: 96901
# Number of files read: 97001
# Number of files read: 97101
# Number of files read: 97201
# Number of files read: 97301
# Number of files read: 97401
# Number of files read: 97501
# Number of files read: 97601
# Number of files read: 97701
# Number of files read: 97801
# Number of files read: 97901
# Number of files read: 98001
# Number of files read: 98101
# Number of files read: 98201
# Number of files read: 98301
# Number of files read: 98401
# Number of files read: 98501
# Number of files read: 98601
# Number of files read: 98701
# Number of files read: 98801
# Number of files read: 98901
# Number of files read: 99001
# Number of files read: 99101
# Number of files read: 99201
# Number of files read: 99301
# Number of files read: 99401
# Number of files read: 99501
# Number of files read: 99601
# Number of files read: 99701
# Number of files read: 99801
# Number of files read: 99901
# Number of files read: 100001
# Number of files read: 100101
# Number of files read: 100201
# Number of files read: 100301
# Number of files read: 100401
# Number of files read: 100501
# Number of files read: 100601
# Number of files read: 100701
# Number of files read: 100801
# Number of files read: 100901
# Number of files read: 101001
# Number of files read: 101101
# Number of files read: 101201
# Number of files read: 101301
# Number of files read: 101401
# Number of files read: 101501
# Number of files read: 101601
# Number of files read: 101701
# Number of files read: 101801
# Number of files read: 101901
# Number of files read: 102001
# Number of files read: 102101
# Number of files read: 102201
# Number of files read: 102301
# Number of files read: 102401
# Number of files read: 102501
# Number of files read: 102601
# Number of files read: 102701
# Number of files read: 102801
# Number of files read: 102901
# Number of files read: 103001
# Number of files read: 103101
# Number of files read: 103201
# Number of files read: 103301
# Number of files read: 103401
# Number of files read: 103501
# Number of files read: 103601
# Number of files read: 103701
# Number of files read: 103801
# Number of files read: 103901
# Number of files read: 104001
# Number of files read: 104101
# Number of files read: 104201
# Number of files read: 104301
# Number of files read: 104401
# Number of files read: 104501
# Number of files read: 104601
# Number of files read: 104701
# Number of files read: 104801
# Number of files read: 104901
# Number of files read: 105001
# Number of files read: 105101
# Number of files read: 105201
# Number of files read: 105301
# Number of files read: 105401
# Number of files read: 105501
# Number of files read: 105601
# Number of files read: 105701
# Number of files read: 105801
# Number of files read: 105901
# Number of files read: 106001
# Number of files read: 106101
# Number of files read: 106201
# Number of files read: 106301
# Number of files read: 106401
# Number of files read: 106501
# Number of files read: 106601
# Number of files read: 106701
# Number of files read: 106801
# Number of files read: 106901
# Number of files read: 107001
# Number of files read: 107101
# Number of files read: 107201
# Number of files read: 107301
# Number of files read: 107401
# Number of files read: 107501
# Number of files read: 107601
# Number of files read: 107701
# Number of files read: 107801
# Number of files read: 107901
# Number of files read: 108001
# Number of files read: 108101
# Number of files read: 108201
# Number of files read: 108301
# Number of files read: 108401
# Number of files read: 108501
# Number of files read: 108601
# Number of files read: 108701
# Number of files read: 108801
# Number of files read: 108901
# Number of files read: 109001
# Number of files read: 109101
# Number of files read: 109201
# Number of files read: 109301
# Number of files read: 109401
# Number of files read: 109501
# Number of files read: 109601
# Number of files read: 109701
# Number of files read: 109801
# Number of files read: 109901
# Number of files read: 110001
# Number of files read: 110101
# Number of files read: 110201
# Number of files read: 110301
# Number of files read: 110401
# Number of files read: 110501
# Number of files read: 110601
# Number of files read: 110701
# Number of files read: 110801
# Number of files read: 110901
# Number of files read: 111001
# Number of files read: 111101
# Number of files read: 111201
# Number of files read: 111301
# Number of files read: 111401
# Number of files read: 111501
# Number of files read: 111601
# Number of files read: 111701
# Number of files read: 111801
# Number of files read: 111901
# Number of files read: 112001
# Number of files read: 112101
# Number of files read: 112201
# Number of files read: 112301
# Number of files read: 112401
# Number of files read: 112501
# Number of files read: 112601
# Number of files read: 112701
# Number of files read: 112801
# Number of files read: 112901
# Number of files read: 113001
# Number of files read: 113101
# Number of files read: 113201
# Number of files read: 113301
# Number of files read: 113401
# Number of files read: 113501
# Number of files read: 113601
# Number of files read: 113701
# Number of files read: 113801
# Number of files read: 113901
# Number of files read: 114001
# Number of files read: 114101
# Number of files read: 114201
# Number of files read: 114301
# Number of files read: 114401
# Number of files read: 114501
# Number of files read: 114601
# Number of files read: 114701
# Number of files read: 114801
# Number of files read: 114901
# Number of files read: 115001
# Number of files read: 115101
# Number of files read: 115201
# Number of files read: 115301
# Number of files read: 115401
# Number of files read: 115501
# Number of files read: 115601
# Number of files read: 115701
# Number of files read: 115801
# Number of files read: 115901
# Number of files read: 116001
# Number of files read: 116101
# Number of files read: 116201
# Number of files read: 116301
# Number of files read: 116401
# Number of files read: 116501
# Number of files read: 116601
# Number of files read: 116701
# Number of files read: 116801
# Number of files read: 116901
# Number of files read: 117001
# Number of files read: 117101
# Number of files read: 117201
# Number of files read: 117301
# Number of files read: 117401
# Number of files read: 117501
# Number of files read: 117601
# Number of files read: 117701
# Number of files read: 117801
# Number of files read: 117901
# Number of files read: 118001
# Number of files read: 118101
# Number of files read: 118201
# Number of files read: 118301
# Number of files read: 118401
# Number of files read: 118501
# Number of files read: 118601
# Number of files read: 118701
# Number of files read: 118801
# Number of files read: 118901
# Number of files read: 119001
# Number of files read: 119101
# Number of files read: 119201
# Number of files read: 119301
# Number of files read: 119401
# Number of files read: 119501
# Number of files read: 119601
# Number of files read: 119701
# Number of files read: 119801
# Number of files read: 119901
# Number of files read: 120001
# Number of files read: 120101
# Number of files read: 120201
# Number of files read: 120301
# Number of files read: 120401
# Number of files read: 120501
# Number of files read: 120601
# Number of files read: 120701
# Number of files read: 120801
# Number of files read: 120901
# Number of files read: 121001
# Number of files read: 121101
# Number of files read: 121201
# Number of files read: 121301
# Number of files read: 121401
# Number of files read: 121501
# Number of files read: 121601
# Number of files read: 121701
# Number of files read: 121801
# Number of files read: 121901
# Number of files read: 122001
# Number of files read: 122101
# Number of files read: 122201
# Number of files read: 122301
# Number of files read: 122401
# Number of files read: 122501
# Number of files read: 122601
# Number of files read: 122701
# Number of files read: 122801
# Number of files read: 122901
# Number of files read: 123001
# Number of files read: 123101
# Number of files read: 123201
# Number of files read: 123301
# Number of files read: 123401
# Number of files read: 123501
# Number of files read: 123601
# Number of files read: 123701
# Number of files read: 123801
# Number of files read: 123901
# Number of files read: 124001
# Number of files read: 124101
# Number of files read: 124201
# Number of files read: 124301
# Number of files read: 124401
# Number of files read: 124501
# Number of files read: 124601
# Number of files read: 124701
# Number of files read: 124801
# Number of files read: 124901
# Number of files read: 125001
# Number of files read: 125101
# Number of files read: 125201
# Number of files read: 125301
# Number of files read: 125401
# Number of files read: 125501
# Number of files read: 125601
# Number of files read: 125701
# Number of files read: 125801
# Number of files read: 125901
# Number of files read: 126001
# Number of files read: 126101
# Number of files read: 126201
# Number of files read: 126301
# Number of files read: 126401
# Number of files read: 126501
# Number of files read: 126601
# Number of files read: 126701
# Number of files read: 126801
# Number of files read: 126901
# Number of files read: 127001
# Number of files read: 127101
# Number of files read: 127201
# Number of files read: 127301
# Number of files read: 127401
# Number of files read: 127501
# Number of files read: 127601
# Number of files read: 127701
# Number of files read: 127801
# Number of files read: 127901
# Number of files read: 128001
# Number of files read: 128101
# Number of files read: 128201
# Number of files read: 128301
# Number of files read: 128401
# Number of files read: 128501
# Number of files read: 128601
# Number of files read: 128701
# Number of files read: 128801
# Number of files read: 128901
# Number of files read: 129001
# Number of files read: 129101
# Number of files read: 129201
# Number of files read: 129301
# Number of files read: 129401
# Number of files read: 129501
# Number of files read: 129601
# Number of files read: 129701
# Number of files read: 129801
# Number of files read: 129901
# Number of files read: 130001
# Number of files read: 130101
# Number of files read: 130201
# Number of files read: 130301
# Number of files read: 130401
# Number of files read: 130501
# Number of files read: 130601
# Number of files read: 130701
# Number of files read: 130801
# Number of files read: 130901
# Number of files read: 131001
# Number of files read: 131101
# Number of files read: 131201
# Number of files read: 131301
# Number of files read: 131401
# Number of files read: 131501
# Number of files read: 131601
# Number of files read: 131701
# Number of files read: 131801
# Number of files read: 131901
# Number of files read: 132001
# Number of files read: 132101
# Number of files read: 132201
# Number of files read: 132301
# Number of files read: 132401
# Number of files read: 132501
# Number of files read: 132601
# Number of files read: 132701
# Number of files read: 132801
# Number of files read: 132901
# Number of files read: 133001
# Number of files read: 133101
# Number of files read: 133201
# Number of files read: 133301
# Number of files read: 133401
# Number of files read: 133501
# Number of files read: 133601
# Number of files read: 133701
# Number of files read: 133801
# Number of files read: 133901
# Number of files read: 134001
# Number of files read: 134101
# Number of files read: 134201
# Number of files read: 134301
# Number of files read: 134401
# Number of files read: 134501
# Number of files read: 134601
# Number of files read: 134701
# Number of files read: 134801
# Number of files read: 134901
# Number of files read: 135001
# Number of files read: 135101
# Number of files read: 135201
# Number of files read: 135301
# Number of files read: 135401
# Number of files read: 135501
# Number of files read: 135601
# Number of files read: 135701
# Number of files read: 135801
# Number of files read: 135901
# Number of files read: 136001
# Number of files read: 136101
# Number of files read: 136201
# Number of files read: 136301
# Number of files read: 136401
# Number of files read: 136501
# Number of files read: 136601
# Number of files read: 136701
# Number of files read: 136801
# Number of files read: 136901
# Number of files read: 137001
# Number of files read: 137101
# Number of files read: 137201
# Number of files read: 137301
# Number of files read: 137401
# Number of files read: 137501
# Number of files read: 137601
# Number of files read: 137701
# Number of files read: 137801
# Number of files read: 137901
# Number of files read: 138001
# Number of files read: 138101
# Number of files read: 138201
# Number of files read: 138301
# Number of files read: 138401
# Number of files read: 138501
# Number of files read: 138601
# Number of files read: 138701
# Number of files read: 138801
# Number of files read: 138901
# Number of files read: 139001
# Number of files read: 139101
# Number of files read: 139201
# Number of files read: 139301
# Number of files read: 139401
# Number of files read: 139501
# Number of files read: 139601
# Number of files read: 139701
# Number of files read: 139801
# Number of files read: 139901
# Number of files read: 140001
# Number of files read: 140101
# Number of files read: 140201
# Number of files read: 140301
# Number of files read: 140401
# Number of files read: 140501
# Number of files read: 140601
# Number of files read: 140701
# Number of files read: 140801
# Number of files read: 140901
# Number of files read: 141001
# Number of files read: 141101
# Number of files read: 141201
# Number of files read: 141301
# Number of files read: 141401
# Number of files read: 141501
# Number of files read: 141601
# Number of files read: 141701
# Number of files read: 141801
# Number of files read: 141901
# Number of files read: 142001
# Number of files read: 142101
# Number of files read: 142201
# Number of files read: 142301
# Number of files read: 142401
# Number of files read: 142501
# Number of files read: 142601
# Number of files read: 142701
# Number of files read: 142801
# Number of files read: 142901
# Number of files read: 143001
# Number of files read: 143101
# Number of files read: 143201
# Number of files read: 143301
# Number of files read: 143401
# Number of files read: 143501
# Number of files read: 143601
# Number of files read: 143701
# Number of files read: 143801
# Number of files read: 143901
# Number of files read: 144001
# Number of files read: 144101
# Number of files read: 144201
# Number of files read: 144301
# Number of files read: 144401
# Number of files read: 144501
# Number of files read: 144601
# Number of files read: 144701
# Number of files read: 144801
# Number of files read: 144901
# Number of files read: 145001
# Number of files read: 145101
# Number of files read: 145201
# Number of files read: 145301
# Number of files read: 145401
# Number of files read: 145501
# Number of files read: 145601
# Number of files read: 145701
# Number of files read: 145801
# Number of files read: 145901
# Number of files read: 146001
# Number of files read: 146101
# Number of files read: 146201
# Number of files read: 146301
# Number of files read: 146401
# Number of files read: 146501
# Number of files read: 146601
# Number of files read: 146701
# Number of files read: 146801
# Number of files read: 146901
# Number of files read: 147001
# Number of files read: 147101
# Number of files read: 147201
# Number of files read: 147301
# Number of files read: 147401
# Number of files read: 147501
# Number of files read: 147601
# Number of files read: 147701
# Number of files read: 147801
# Number of files read: 147901
# Number of files read: 148001
# Number of files read: 148101
# Number of files read: 148201
# Number of files read: 148301
# Number of files read: 148401
# Number of files read: 148501
# Number of files read: 148601
# Number of files read: 148701
# Number of files read: 148801
# Number of files read: 148901
# Number of files read: 149001
# Number of files read: 149101
# Number of files read: 149201
# Number of files read: 149301
# Number of files read: 149401
# Number of files read: 149501
# Number of files read: 149601
# Number of files read: 149701
# Number of files read: 149801
# Number of files read: 149901
# Number of files read: 150001
# Number of files read: 150101
# Number of files read: 150201
# Number of files read: 150301
# Number of files read: 150401
# Number of files read: 150501
# Number of files read: 150601
# Number of files read: 150701
# Number of files read: 150801
# Number of files read: 150901
# Number of files read: 151001
# Number of files read: 151101
# Number of files read: 151201
# Number of files read: 151301
# Number of files read: 151401
# Number of files read: 151501
# Number of files read: 151601
# Number of files read: 151701
# Number of files read: 151801
# Number of files read: 151901
# Number of files read: 152001
# Number of files read: 152101
# Number of files read: 152201
# Number of files read: 152301
# Number of files read: 152401
# Number of files read: 152501
# Number of files read: 152601
# Number of files read: 152701
# Number of files read: 152801
# Number of files read: 152901
# Number of files read: 153001
# Number of files read: 153101
# Number of files read: 153201
# Number of files read: 153301
# Number of files read: 153401
# Number of files read: 153501
# Number of files read: 153601
# Number of files read: 153701
# Number of files read: 153801
# Number of files read: 153901
# Number of files read: 154001
# Number of files read: 154101
# Number of files read: 154201
# Number of files read: 154301
# Number of files read: 154401
# Number of files read: 154501
# Number of files read: 154601
# Number of files read: 154701
# Number of files read: 154801
# Number of files read: 154901
# Number of files read: 155001
# Number of files read: 155101
# Number of files read: 155201
# Number of files read: 155301
# Number of files read: 155401
# Number of files read: 155501
# Number of files read: 155601
# Number of files read: 155701
# Number of files read: 155801
# Number of files read: 155901
# Number of files read: 156001
# Number of files read: 156101
# Number of files read: 156201
# Number of files read: 156301
# Number of files read: 156401
# Number of files read: 156501
# Number of files read: 156601
# Number of files read: 156701
# Number of files read: 156801
# Number of files read: 156901
# Number of files read: 157001
# Number of files read: 157101
# Number of files read: 157201
# Number of files read: 157301
# Number of files read: 157401
# Number of files read: 157501
# Number of files read: 157601
# Number of files read: 157701
# Number of files read: 157801
# Number of files read: 157901
# Number of files read: 158001
# Number of files read: 158101
# Number of files read: 158201
# Number of files read: 158301
# Number of files read: 158401
# Number of files read: 158501
# Number of files read: 158601
# Number of files read: 158701
# Number of files read: 158801
# Number of files read: 158901
# Number of files read: 159001
# Number of files read: 159101
# Number of files read: 159201
# Number of files read: 159301
# Number of files read: 159401
# Number of files read: 159501
# Number of files read: 159601
# Number of files read: 159701
# Number of files read: 159801
# Number of files read: 159901
# Number of files read: 160001
# Number of files read: 160101
# Number of files read: 160201
# Number of files read: 160301
# Number of files read: 160401
# Number of files read: 160501
# Number of files read: 160601
# Number of files read: 160701
# Number of files read: 160801
# Number of files read: 160901
# Number of files read: 161001
# Number of files read: 161101
# Number of files read: 161201
# Number of files read: 161301
# Number of files read: 161401
# Number of files read: 161501
# Number of files read: 161601
# Number of files read: 161701
# Number of files read: 161801
# Number of files read: 161901
# Number of files read: 162001
# Number of files read: 162101
# Number of files read: 162201
# Number of files read: 162301
# Number of files read: 162401
# Number of files read: 162501
# Number of files read: 162601
# Number of files read: 162701
# Number of files read: 162801
# Number of files read: 162901
# Number of files read: 163001
# Number of files read: 163101
# Number of files read: 163201
# Number of files read: 163301
# Number of files read: 163401
# Number of files read: 163501
# Number of files read: 163601
# Number of files read: 163701
# Number of files read: 163801
# Number of files read: 163901
# Number of files read: 164001
# Number of files read: 164101
# Number of files read: 164201
# Number of files read: 164301
# Number of files read: 164401
# Number of files read: 164501
# Number of files read: 164601
# Number of files read: 164701
# Number of files read: 164801
# Number of files read: 164901
# Number of files read: 165001
# Number of files read: 165101
# Number of files read: 165201
# Number of files read: 165301
# Number of files read: 165401

# %%
concat_text_trunc_df = pd.DataFrame.from_dict(covid19_dict,orient='index')
concat_text_trunc_df
# Out:
#          cord_uid                                           sentence  \
# 0        wvx6q999  The situation has continued to evolve rapidly ...
# 1        wvx6q999  In this issue of Eurosurveillance, we are publ...
# 2        wvx6q999  Today, the WHO Director-General Tedros Adhanom...
# 3        wvx6q999  International health organisations such as the...
# 4        wvx6q999  At the end of 2019, on 31 December, the World ...
# ...           ...                                                ...
# 1109048  byehf0wn  The molecular mechanisms underlying the differ...
# 1109049  byehf0wn  The discussed data show the importance of macr...
# 1109050  byehf0wn                                              None.
# 1109051  byehf0wn  The author is supported by MIUR and University...
# 1109052  byehf0wn  Characteristics of SARS-CoV-2 patients dying i...
#
#                 section
# 0
# 1
# 2
# 3
# 4
# ...                 ...
# 1109048      Hypotheses
# 1109049     Conclusions
# 1109050     Disclosures
# 1109051         Funding
# 1109052  Web reference:
#
# [1109053 rows x 3 columns]

# %%
concat_text_trunc_df.to_json(full_text_df_outfile_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-eb25d974679e> in <module>
# ----> 1 concat_text_trunc_df.to_json(full_text_df_outfile_path)
#
# NameError: name 'full_text_df_outfile_path' is not defined

# %%
print('Number of papers extracted:',len(concat_text_trunc_df.cord_uid.unique()))
# Out:
# Number of papers extracted: 33218

# %%
"""
Functions to generate regex match patterns from synonymous words/phrases for filtering subject headers
"""

import re

def extract_regex_pattern(section_list, pattern):
    r = re.compile(pattern, re.IGNORECASE)
    extracted_list = list(filter(r.match, section_list))
    remaining_list = list(set(section_list) - set(extracted_list))
    
    return remaining_list, extracted_list

def construct_regex_match_pattern(terms_dict):
    fuzzy_terms = ['.*%s.*' % i for i in terms_dict['fuzzy']]
    exact_terms = terms_dict['exact']
    
    fuzzy_pattern = '|'.join(fuzzy_terms)
    #exact_pattern = '|'.join(exact_terms)
    
    full_pattern = fuzzy_pattern
    
    return full_pattern

# %%
"""
Extract putative discussion headers.
"""

#Construct regex pattern for discussion header terms and extract list of matching headers.

disc_terms_dict = {
    'exact': [],
    'fuzzy' : [
        'conclusion',
        'discussion',
        'interpretation',
        'added value of this study',
        'research in context',
        'concluding',
        'closing remarks',
        'summary of findings',
        'outcome'
    ]
}
conc_pattern = construct_regex_match_pattern(disc_terms_dict)
print(conc_pattern)
# Out:
# .*conclusion.*|.*discussion.*|.*interpretation.*|.*added value of this study.*|.*research in context.*|.*concluding.*|.*closing remarks.*|.*summary of findings.*|.*outcome.*

# %%
import pprint

#unique_sections = set(merged_text_vec_df.section.tolist())
unique_sections = set(concat_text_trunc_df.section.tolist())

rem_header_list, ext_header_list = extract_regex_pattern(unique_sections, conc_pattern)

print("Number of discussion headers: %d" % len(ext_header_list))
print("Example discussion headers:")
pprint.pprint(ext_header_list[:20])
# Out:
# Number of discussion headers: 7873
# Example discussion headers:
# ['Outcome measures and definitions ::: MATERIAL AND METHODS',
#  '4 Discussion and limitation',
#  'Public health expenditure and Covid-19 outcomes ::: Conceptual background '
#  'and hypotheses',
#  'CONCLUSIONS AND IMPLICATIONS',
#  'Docking results of Lonafarnib against SARS‐CoV‐2 and SARS‐CoV NSP12‐NSP7 ::: '
#  'RESULTS AND DISCUSSION',
#  'Treatment ::: Treatment and Outcome',
#  'Discussion and suggestions of safety for urban public transportation',
#  '4.1. Temporal Trend ::: 4. Discussion',
#  'Conclusion: Further Regulatory Action is Needed',
#  'Types of outcome measures ::: Methods and analysis',
#  'Limitations. ::: DISCUSSION',
#  'Case Discussion',
#  '“Parallel pleura sign” ::: Other accompanying signs ::: Discussion',
#  'Safety outcome ::: Results',
#  'Secondary outcomes ::: Outcome measures ::: Methods',
#  'Conclusion and Future Scopes',
#  'Outcomes after COVID-19',
#  'Discussion of East Asian prejudice vs. Neutral',
#  'Cyclic amide derivatives (12–20) ::: Results and discussion',
#  'Pleiotropic associations with disease outcomes ::: RESULTS']

# %%
#For now, lower-casing all section headers for matching

section_exact_match_list = set([i.lower() for i in ext_header_list])
section_exact_match_list.add('abstract')
section_exact_match_list.add('title')

print("Number of sections filtering to: %d" % len(section_exact_match_list))
# Out:
# Number of sections filtering to: 7379

# %%
print('Step 3: Filtering to title, abstract and discussion sections...')
merged_df_filtered_to_sections_oi = concat_text_trunc_df.loc[concat_text_trunc_df.section.str.lower().isin(section_exact_match_list)]

#merged_df_filtered_to_sections_oi.to_csv(filt_text_df_outfile_path, index=False)
# Out:
# Step 3: Filtering to title, abstract and discussion sections...

# %%
#version 20200718
print('Number of papers after filtering to sections:',len(merged_df_filtered_to_sections_oi.cord_uid.unique()))
# Out:
# Number of papers after filtering to sections: 18759

# %%
#v31 output
print('Number of papers after filtering to sections:',len(merged_df_filtered_to_sections_oi.cord_uid.unique()))
# Out:
# Number of papers after filtering to sections: 13465

# %%
"""
Filtering out sentences with less than three non-header words.

Author: Malavika Suresh

"""
input_data = merged_df_filtered_to_sections_oi

# %%
#Keep only sentences containing at least 3 words other than those defined below
#This also removes any sentences that do not contain any words at all

print('Step 4: Filtering our noisy sentences...')
rep = {"text": "", "cite_spans": "", "ref_spans": "", "section": "", "abstract": "",\
       "biorxiv preprint": "", "medrxiv preprint": "", "doi:": ""}
rep = dict((re.escape(k), v) for k, v in rep.items())
pattern = re.compile("|".join(rep.keys()))
sentences_temp = [pattern.sub(lambda m: rep[re.escape(m.group(0))], s) for s in input_data.sentence.str.lower()]
pattern = re.compile(".*[A-Za-z].*")
sentences_to_keep = [(bool(re.search(pattern,s))) & (len(s.split(' '))>2) for s in sentences_temp]
input_processed = input_data.loc[sentences_to_keep,:]
sentences_to_drop = [not i for i in sentences_to_keep]
input_excluded = input_data.loc[sentences_to_drop,:]
# Out:
# Step 4: Filtering our noisy sentences...

# %%
print('Number of papers after filtering sentences:',len(input_processed.cord_uid.unique()))
# Out:
# Number of papers after filtering sentences: 23435

# %%
#version 20200718
print('Number of papers after filtering sentences:',len(input_processed.cord_uid.unique()))
# Out:
# Number of papers after filtering sentences: 18662

# %%
#v31 output
print('Number of papers after filtering sentences:',len(input_processed.cord_uid.unique()))
# Out:
# Number of papers after filtering sentences: 13390

# %%
input_processed.to_csv(processed_text_df_outfile_path)
# input_excluded.to_csv('%scord_titles_abstracts_conclusions_excluded.csv' % output_path)

# %%
input_processed
# Out:
#         cord_uid                                           sentence  \
# 17      dwrazfli  The crisis generated by the COVID-19 pandemic ...
# 22      5k0ktboh  Asymptomatic and atypical presentations of COV...
# 23      5k0ktboh  The patient's radiological findings were enoug...
# 24      5k0ktboh  The atypical presentation and lack of communic...
# 25      5k0ktboh  Asymptomatic and atypical presentations of COV...
# ...          ...                                                ...
# 867265  6lr8i54a  Currently, there is a Phase III trial (ChiCTR2...
# 867266  6lr8i54a  Although there is good evidence of tocilizumab...
# 867267  6lr8i54a  Although tocilizumab seems like a good option ...
# 867268  6lr8i54a  To summarize, we report the usage of tocilizum...
# 867269  6lr8i54a  There are still many things we have to learn i...
#
#             section
# 17      Conclusions
# 22       Discussion
# 23       Discussion
# 24       Discussion
# 25       Conclusion
# ...             ...
# 867265   Discussion
# 867266   Discussion
# 867267   Discussion
# 867268   Discussion
# 867269   Discussion
#
# [123372 rows x 3 columns]

# %%
title_data = input_processed.loc[input_processed.section.str.lower()=='title',:]
abstract_data = input_processed.loc[input_processed.section.str.lower()=='abstract',:]
conclusion_data = input_processed.loc[(input_processed.section.str.lower()!='title') & (input_processed.section.str.lower()!='abstract'),:]

# %%
print('Number of papers:', input_processed.cord_uid.nunique())
print('Number of papers with title:', title_data.cord_uid.nunique())
print('Number of papers with abstract:', abstract_data.cord_uid.nunique())
print('Number of papers with conclusion:', conclusion_data.cord_uid.nunique())
# Out:
# Number of papers: 23435
# Number of papers with title: 3
# Number of papers with abstract: 18149
# Number of papers with conclusion: 18621

# %%
#version 20200718
print('Number of papers:', input_processed.cord_uid.nunique())
print('Number of papers with title:', title_data.cord_uid.nunique())
print('Number of papers with abstract:', abstract_data.cord_uid.nunique())
print('Number of papers with conclusion:', conclusion_data.cord_uid.nunique())
# Out:
# Number of papers: 18662
# Number of papers with title: 3
# Number of papers with abstract: 14467
# Number of papers with conclusion: 14717

# %%
#v31 output
print('Number of papers:', input_processed.cord_uid.nunique())
print('Number of papers with title:', title_data.cord_uid.nunique())
print('Number of papers with abstract:', abstract_data.cord_uid.nunique())
print('Number of papers with conclusion:', conclusion_data.cord_uid.nunique())
# Out:
# Number of papers: 13390
# Number of papers with title: 2
# Number of papers with abstract: 10539
# Number of papers with conclusion: 10408
