# %%
import os
import re
import ast
import numpy as np
import pandas as pd
import glob
import json

from pandas.io.json import json_normalize

from zipfile import ZipFile

from sklearn.metrics.pairwise import cosine_similarity

from numba import jit

# %%
"""
Preprocessing Cord-19 text files

Goal: Filter text and vector files containing publications (1 sentence per row) to publications 
relevant to Covid-19 and specified columns.  Merge into a single file for extraction of sentences/vectors
belonging to specified papers/sections.

Steps:
    1. Filter metadata.csv (from Kaggle Cord-19 dataset) to paper cord_uids for papers where:
        -Title or Abstract contains 1 or more Covid-19 synonyms.
        -Publication date is after 2019-10-01.
        This has been moved to notebook covid_vt_contra_metadata_filtering.ipynb
        
    2.  Load all full text files (json format) as pandas dataframes and truncate them to:
            -Rows containing cord_uids from step 1
            -Columns cord_uid, sentence, and section

        Write truncated text dataframe to json.
    
    5.  Filter to title, abstract and discussion sections
    
    6.  Filter out noisy sentences (with <3 words, etc.)
"""
# Out:
# '\nPreprocessing Cord-19 text files\n\nGoal: Filter text and vector files containing publications (1 sentence per row) to publications \nrelevant to Covid-19 and specified columns.  Merge into a single file for extraction of sentences/vectors\nbelonging to specified papers/sections.\n\nSteps:\n    1. Filter metadata.csv (from Kaggle Cord-19 dataset) to paper cord_uids for papers where:\n        -Title or Abstract contains 1 or more Covid-19 synonyms.\n        -Publication date is after 2019-10-01.\n        This has been moved to notebook covid_vt_contra_metadata_filtering.ipynb\n        \n    2.  Load all full text files (parquet format) as pandas dataframes and truncate them to:\n            -Rows containing cord_uids from step 1\n            -Columns cord_uid, sentence_id, sentence, and section\n\n        Write truncated text dataframes to csv files.\n\n    3.  Merge truncated text dataframes and extract list of sentence_ids for truncating vector files.\n    \n    4.  Load all vector files (parquet format) as pandas dataframes and truncate them to:\n            -Rows containing sentence_ids from step 3.\n        \n        Write truncated vector dataframes to csv files.\n    \n    5.  Merge truncated vector dataframes and join with merged truncated text files (merged_text_vector_df).\n    \n    6.  Write merged, truncated vector and text dataframe to csv file.\n'

# %%
"""
Input and Output file paths.  This will be turned into a config file that can be passed as an argument.
"""

#Input
resources_path = '../data/kaggle_cord19/'

metadata_csv_path = '../data/v31_processed/covid19_date_filt_metadata_200620.csv'
covid_19_term_list_file = '../data/kaggle_cord19/virus_words.txt'

json_text_file_dir = '../data/kaggle_cord19/json_v31.zip'
json_temp_path = '..\\data\\kaggle_cord19\\Extracted\\'
json_temp_path_fmt = '../data/kaggle_cord19/Extracted/'

pub_date_cutoff = '2019-10-01'

#Output

output_path = '../data/v31_processed/'

full_text_df_outfile_path = '%s..\\data\\v31_processed\\full_text_200620.json' %output_path
filt_text_df_outfile_path = '%sfilt_text_df_200620.csv' % output_path
processed_text_df_outfile_path = '%scord_titles_abstracts_conclusions_200620.csv' % output_path

# %%
#Main

print("Step 1: Filtering metadata csv by Covid-19 synoynms and publication date...")
#Replacing this step with the output of notebook covid_vt_contra_metadata_filtering.ipynb
covid19_df = pd.read_csv(metadata_csv_path)
uid_list = covid19_df.cord_uid.tolist()

pdf_filenames = list(covid19_df.pdf_json_files)
pmc_filenames = list(covid19_df.pmc_json_files)

covid19_dict = {}

print("Step 2: Loading full text dataframes, filtering to extracted uids...")
#truncate_pq_text_files(pq_text_file_dir, pq_text_files_cols_oi, csv_trunc_text_file_dir, uid_list)
with ZipFile(json_text_file_dir, 'r') as zipObj:
    listOfFileNames = zipObj.namelist()
    print('Number of files to iterate over:',len(listOfFileNames))
    k = 0
    iter_num = 0
    for fileName in listOfFileNames:
        iter_num = iter_num + 1
        # Check filename ends with json and file exists in filtered list of cord papers
        if (fileName in pdf_filenames) or (fileName in pmc_filenames):
            zipObj.extract(fileName,json_temp_path)
            json_op = []
            with open(json_temp_path_fmt+fileName,'r', encoding='utf8') as f:
                temp = []
                temp.append("".join([line.replace('\n', '').replace('\r','').replace('\t','') for line in f]))
                for jsonObj in temp:
                    json_dict = json.loads(jsonObj, encoding='utf8')
                    json_op.append(json_dict)
                    for i in range(len(json_op)):
                        temp_json = json_normalize(json_op[i])
                        try:
                            covid19_dict[k]={'cord_uid':list(covid19_df.loc[((fileName==covid19_df.pdf_json_files) | (fileName==covid19_df.pmc_json_files)),'cord_uid'])[0],
                                         'sentence':temp_json['abstract'][0][0]['text'],
                                         'section':temp_json['abstract'][0][0]['section']}
                            k = k + 1
                        except:
                            abstract = ''
                        
                        for j,temp_dict in enumerate(temp_json['body_text'][0]):
                            covid19_dict[k]={'cord_uid':list(covid19_df.loc[((fileName==covid19_df.pdf_json_files) | (fileName==covid19_df.pmc_json_files)),'cord_uid'])[0],
                                             'sentence':temp_json['body_text'][0][j]['text'],
                                             'section':temp_json['body_text'][0][j]['section']}
                            k = k + 1
                        
        if iter_num%100==0:
            print('Number of files read:',iter_num)
            #break
print('Number of rows added:',k)
# Out:
# Step 1: Filtering metadata csv by Covid-19 synoynms and publication date...
# Step 2: Loading full text dataframes, filtering to extracted uids, and writing to csv files...
# Number of files to iterate over: 129922
# C:\Users\SuresMal\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# Number of files read: 100
# Number of files read: 200
# Number of files read: 300
# Number of files read: 400
# Number of files read: 500
# Number of files read: 600
# Number of files read: 700
# Number of files read: 800
# Number of files read: 900
# Number of files read: 1000
# Number of files read: 1100
# Number of files read: 1200
# Number of files read: 1300
# Number of files read: 1400
# Number of files read: 1500
# Number of files read: 1600
# Number of files read: 1700
# Number of files read: 1800
# Number of files read: 1900
# Number of files read: 2000
# Number of files read: 2100
# Number of files read: 2200
# Number of files read: 2300
# Number of files read: 2400
# Number of files read: 2500
# Number of files read: 2600
# Number of files read: 2700
# Number of files read: 2800
# Number of files read: 2900
# Number of files read: 3000
# Number of files read: 3100
# Number of files read: 3200
# Number of files read: 3300
# Number of files read: 3400
# Number of files read: 3500
# Number of files read: 3600
# Number of files read: 3700
# Number of files read: 3800
# Number of files read: 3900
# Number of files read: 4000
# Number of files read: 4100
# Number of files read: 4200
# Number of files read: 4300
# Number of files read: 4400
# Number of files read: 4500
# Number of files read: 4600
# Number of files read: 4700
# Number of files read: 4800
# Number of files read: 4900
# Number of files read: 5000
# Number of files read: 5100
# Number of files read: 5200
# Number of files read: 5300
# Number of files read: 5400
# Number of files read: 5500
# Number of files read: 5600
# Number of files read: 5700
# Number of files read: 5800
# Number of files read: 5900
# Number of files read: 6000
# Number of files read: 6100
# Number of files read: 6200
# Number of files read: 6300
# Number of files read: 6400
# Number of files read: 6500
# Number of files read: 6600
# Number of files read: 6700
# Number of files read: 6800
# Number of files read: 6900
# Number of files read: 7000
# Number of files read: 7100
# Number of files read: 7200
# Number of files read: 7300
# Number of files read: 7400
# Number of files read: 7500
# Number of files read: 7600
# Number of files read: 7700
# Number of files read: 7800
# Number of files read: 7900
# Number of files read: 8000
# Number of files read: 8100
# Number of files read: 8200
# Number of files read: 8300
# Number of files read: 8400
# Number of files read: 8500
# Number of files read: 8600
# Number of files read: 8700
# Number of files read: 8800
# Number of files read: 8900
# Number of files read: 9000
# Number of files read: 9100
# Number of files read: 9200
# Number of files read: 9300
# Number of files read: 9400
# Number of files read: 9500
# Number of files read: 9600
# Number of files read: 9700
# Number of files read: 9800
# Number of files read: 9900
# Number of files read: 10000
# Number of files read: 10100
# Number of files read: 10200
# Number of files read: 10300
# Number of files read: 10400
# Number of files read: 10500
# Number of files read: 10600
# Number of files read: 10700
# Number of files read: 10800
# Number of files read: 10900
# Number of files read: 11000
# Number of files read: 11100
# Number of files read: 11200
# Number of files read: 11300
# Number of files read: 11400
# Number of files read: 11500
# Number of files read: 11600
# Number of files read: 11700
# Number of files read: 11800
# Number of files read: 11900
# Number of files read: 12000
# Number of files read: 12100
# Number of files read: 12200
# Number of files read: 12300
# Number of files read: 12400
# Number of files read: 12500
# Number of files read: 12600
# Number of files read: 12700
# Number of files read: 12800
# Number of files read: 12900
# Number of files read: 13000
# Number of files read: 13100
# Number of files read: 13200
# Number of files read: 13300
# Number of files read: 13400
# Number of files read: 13500
# Number of files read: 13600
# Number of files read: 13700
# Number of files read: 13800
# Number of files read: 13900
# Number of files read: 14000
# Number of files read: 14100
# Number of files read: 14200
# Number of files read: 14300
# Number of files read: 14400
# Number of files read: 14500
# Number of files read: 14600
# Number of files read: 14700
# Number of files read: 14800
# Number of files read: 14900
# Number of files read: 15000
# Number of files read: 15100
# Number of files read: 15200
# Number of files read: 15300
# Number of files read: 15400
# Number of files read: 15500
# Number of files read: 15600
# Number of files read: 15700
# Number of files read: 15800
# Number of files read: 15900
# Number of files read: 16000
# Number of files read: 16100
# Number of files read: 16200
# Number of files read: 16300
# Number of files read: 16400
# Number of files read: 16500
# Number of files read: 16600
# Number of files read: 16700
# Number of files read: 16800
# Number of files read: 16900
# Number of files read: 17000
# Number of files read: 17100
# Number of files read: 17200
# Number of files read: 17300
# Number of files read: 17400
# Number of files read: 17500
# Number of files read: 17600
# Number of files read: 17700
# Number of files read: 17800
# Number of files read: 17900
# Number of files read: 18000
# Number of files read: 18100
# Number of files read: 18200
# Number of files read: 18300
# Number of files read: 18400
# Number of files read: 18500
# Number of files read: 18600
# Number of files read: 18700
# Number of files read: 18800
# Number of files read: 18900
# Number of files read: 19000
# Number of files read: 19100
# Number of files read: 19200
# Number of files read: 19300
# Number of files read: 19400
# Number of files read: 19500
# Number of files read: 19600
# Number of files read: 19700
# Number of files read: 19800
# Number of files read: 19900
# Number of files read: 20000
# Number of files read: 20100
# Number of files read: 20200
# Number of files read: 20300
# Number of files read: 20400
# Number of files read: 20500
# Number of files read: 20600
# Number of files read: 20700
# Number of files read: 20800
# Number of files read: 20900
# Number of files read: 21000
# Number of files read: 21100
# Number of files read: 21200
# Number of files read: 21300
# Number of files read: 21400
# Number of files read: 21500
# Number of files read: 21600
# Number of files read: 21700
# Number of files read: 21800
# Number of files read: 21900
# Number of files read: 22000
# Number of files read: 22100
# Number of files read: 22200
# Number of files read: 22300
# Number of files read: 22400
# Number of files read: 22500
# Number of files read: 22600
# Number of files read: 22700
# Number of files read: 22800
# Number of files read: 22900
# Number of files read: 23000
# Number of files read: 23100
# Number of files read: 23200
# Number of files read: 23300
# Number of files read: 23400
# Number of files read: 23500
# Number of files read: 23600
# Number of files read: 23700
# Number of files read: 23800
# Number of files read: 23900
# Number of files read: 24000
# Number of files read: 24100
# Number of files read: 24200
# Number of files read: 24300
# Number of files read: 24400
# Number of files read: 24500
# Number of files read: 24600
# Number of files read: 24700
# Number of files read: 24800
# Number of files read: 24900
# Number of files read: 25000
# Number of files read: 25100
# Number of files read: 25200
# Number of files read: 25300
# Number of files read: 25400
# Number of files read: 25500
# Number of files read: 25600
# Number of files read: 25700
# Number of files read: 25800
# Number of files read: 25900
# Number of files read: 26000
# Number of files read: 26100
# Number of files read: 26200
# Number of files read: 26300
# Number of files read: 26400
# Number of files read: 26500
# Number of files read: 26600
# Number of files read: 26700
# Number of files read: 26800
# Number of files read: 26900
# Number of files read: 27000
# Number of files read: 27100
# Number of files read: 27200
# Number of files read: 27300
# Number of files read: 27400
# Number of files read: 27500
# Number of files read: 27600
# Number of files read: 27700
# Number of files read: 27800
# Number of files read: 27900
# Number of files read: 28000
# Number of files read: 28100
# Number of files read: 28200
# Number of files read: 28300
# Number of files read: 28400
# Number of files read: 28500
# Number of files read: 28600
# Number of files read: 28700
# Number of files read: 28800
# Number of files read: 28900
# Number of files read: 29000
# Number of files read: 29100
# Number of files read: 29200
# Number of files read: 29300
# Number of files read: 29400
# Number of files read: 29500
# Number of files read: 29600
# Number of files read: 29700
# Number of files read: 29800
# Number of files read: 29900
# Number of files read: 30000
# Number of files read: 30100
# Number of files read: 30200
# Number of files read: 30300
# Number of files read: 30400
# Number of files read: 30500
# Number of files read: 30600
# Number of files read: 30700
# Number of files read: 30800
# Number of files read: 30900
# Number of files read: 31000
# Number of files read: 31100
# Number of files read: 31200
# Number of files read: 31300
# Number of files read: 31400
# Number of files read: 31500
# Number of files read: 31600
# Number of files read: 31700
# Number of files read: 31800
# Number of files read: 31900
# Number of files read: 32000
# Number of files read: 32100
# Number of files read: 32200
# Number of files read: 32300
# Number of files read: 32400
# Number of files read: 32500
# Number of files read: 32600
# Number of files read: 32700
# Number of files read: 32800
# Number of files read: 32900
# Number of files read: 33000
# Number of files read: 33100
# Number of files read: 33200
# Number of files read: 33300
# Number of files read: 33400
# Number of files read: 33500
# Number of files read: 33600
# Number of files read: 33700
# Number of files read: 33800
# Number of files read: 33900
# Number of files read: 34000
# Number of files read: 34100
# Number of files read: 34200
# Number of files read: 34300
# Number of files read: 34400
# Number of files read: 34500
# Number of files read: 34600
# Number of files read: 34700
# Number of files read: 49100
# Number of files read: 49200
# Number of files read: 49300
# Number of files read: 49400
# Number of files read: 49500
# Number of files read: 49600
# Number of files read: 49700
# Number of files read: 49800
# Number of files read: 49900
# Number of files read: 50000
# Number of files read: 50100
# Number of files read: 50200
# Number of files read: 50300
# Number of files read: 50400
# Number of files read: 50500
# Number of files read: 50600
# Number of files read: 50700
# Number of files read: 50800
# Number of files read: 50900
# Number of files read: 51000
# Number of files read: 51100
# Number of files read: 51200
# Number of files read: 51300
# Number of files read: 51400
# Number of files read: 51500
# Number of files read: 51600
# Number of files read: 51700
# Number of files read: 51800
# Number of files read: 51900
# Number of files read: 52000
# Number of files read: 52100
# Number of files read: 52200
# Number of files read: 52300
# Number of files read: 52400
# Number of files read: 52500
# Number of files read: 52600
# Number of files read: 52700
# Number of files read: 52800
# Number of files read: 52900
# Number of files read: 53000
# Number of files read: 53100
# Number of files read: 53200
# Number of files read: 53300
# Number of files read: 53400
# Number of files read: 53500
# Number of files read: 53600
# Number of files read: 53700
# Number of files read: 53800
# Number of files read: 53900
# Number of files read: 54000
# Number of files read: 54100
# Number of files read: 54200
# Number of files read: 54300
# Number of files read: 54400
# Number of files read: 54500
# Number of files read: 54600
# Number of files read: 54700
# Number of files read: 54800
# Number of files read: 54900
# Number of files read: 55000
# Number of files read: 55100
# Number of files read: 55200
# Number of files read: 55300
# Number of files read: 55400
# Number of files read: 55500
# Number of files read: 55600
# Number of files read: 55700
# Number of files read: 55800
# Number of files read: 55900
# Number of files read: 56000
# Number of files read: 56100
# Number of files read: 56200
# Number of files read: 56300
# Number of files read: 56400
# Number of files read: 56500
# Number of files read: 56600
# Number of files read: 56700
# Number of files read: 56800
# Number of files read: 56900
# Number of files read: 57000
# Number of files read: 57100
# Number of files read: 57200
# Number of files read: 57300
# Number of files read: 57400
# Number of files read: 57500
# Number of files read: 57600
# Number of files read: 57700
# Number of files read: 57800
# Number of files read: 57900
# Number of files read: 58000
# Number of files read: 58100
# Number of files read: 58200
# Number of files read: 58300
# Number of files read: 58400
# Number of files read: 58500
# Number of files read: 58600
# Number of files read: 58700
# Number of files read: 58800
# Number of files read: 58900
# Number of files read: 59000
# Number of files read: 59100
# Number of files read: 59200
# Number of files read: 59300
# Number of files read: 59400
# Number of files read: 59500
# Number of files read: 59600
# Number of files read: 59700
# Number of files read: 59800
# Number of files read: 59900
# Number of files read: 60000
# Number of files read: 60100
# Number of files read: 60200
# Number of files read: 60300
# Number of files read: 60400
# Number of files read: 60500
# Number of files read: 60600
# Number of files read: 60700
# Number of files read: 60800
# Number of files read: 60900
# Number of files read: 61000
# Number of files read: 61100
# Number of files read: 61200
# Number of files read: 61300
# Number of files read: 61400
# Number of files read: 61500
# Number of files read: 61600
# Number of files read: 61700
# Number of files read: 61800
# Number of files read: 61900
# Number of files read: 62000
# Number of files read: 62100
# Number of files read: 62200
# Number of files read: 62300
# Number of files read: 62400
# Number of files read: 62500
# Number of files read: 62600
# Number of files read: 62700
# Number of files read: 62800
# Number of files read: 62900
# Number of files read: 63000
# Number of files read: 63100
# Number of files read: 63200
# Number of files read: 63300
# Number of files read: 63400
# Number of files read: 77800
# Number of files read: 77900
# Number of files read: 78000
# Number of files read: 78100
# Number of files read: 78200
# Number of files read: 78300
# Number of files read: 78400
# Number of files read: 78500
# Number of files read: 78600
# Number of files read: 78700
# Number of files read: 78800
# Number of files read: 78900
# Number of files read: 79000
# Number of files read: 79100
# Number of files read: 79200
# Number of files read: 79300
# Number of files read: 79400
# Number of files read: 79500
# Number of files read: 79600
# Number of files read: 79700
# Number of files read: 79800
# Number of files read: 79900
# Number of files read: 80000
# Number of files read: 80100
# Number of files read: 80200
# Number of files read: 80300
# Number of files read: 80400
# Number of files read: 80500
# Number of files read: 80600
# Number of files read: 80700
# Number of files read: 80800
# Number of files read: 80900
# Number of files read: 81000
# Number of files read: 81100
# Number of files read: 81200
# Number of files read: 81300
# Number of files read: 81400
# Number of files read: 81500
# Number of files read: 81600
# Number of files read: 81700
# Number of files read: 81800
# Number of files read: 81900
# Number of files read: 82000
# Number of files read: 82100
# Number of files read: 82200
# Number of files read: 82300
# Number of files read: 82400
# Number of files read: 82500
# Number of files read: 82600
# Number of files read: 82700
# Number of files read: 82800
# Number of files read: 82900
# Number of files read: 83000
# Number of files read: 83100
# Number of files read: 83200
# Number of files read: 83300
# Number of files read: 83400
# Number of files read: 83500
# Number of files read: 83600
# Number of files read: 83700
# Number of files read: 83800
# Number of files read: 83900
# Number of files read: 84000
# Number of files read: 84100
# Number of files read: 84200
# Number of files read: 84300
# Number of files read: 84400
# Number of files read: 84500
# Number of files read: 84600
# Number of files read: 84700
# Number of files read: 84800
# Number of files read: 84900
# Number of files read: 85000
# Number of files read: 85100
# Number of files read: 85200
# Number of files read: 85300
# Number of files read: 85400
# Number of files read: 85500
# Number of files read: 85600
# Number of files read: 85700
# Number of files read: 85800
# Number of files read: 85900
# Number of files read: 86000
# Number of files read: 86100
# Number of files read: 86200
# Number of files read: 86300
# Number of files read: 86400
# Number of files read: 86500
# Number of files read: 86600
# Number of files read: 86700
# Number of files read: 86800
# Number of files read: 86900
# Number of files read: 87000
# Number of files read: 87100
# Number of files read: 87200
# Number of files read: 87300
# Number of files read: 87400
# Number of files read: 87500
# Number of files read: 87600
# Number of files read: 87700
# Number of files read: 87800
# Number of files read: 87900
# Number of files read: 88000
# Number of files read: 88100
# Number of files read: 88200
# Number of files read: 88300
# Number of files read: 88400
# Number of files read: 88500
# Number of files read: 88600
# Number of files read: 88700
# Number of files read: 88800
# Number of files read: 88900
# Number of files read: 89000
# Number of files read: 89100
# Number of files read: 89200
# Number of files read: 89300
# Number of files read: 89400
# Number of files read: 89500
# Number of files read: 89600
# Number of files read: 89700
# Number of files read: 89800
# Number of files read: 89900
# Number of files read: 90000
# Number of files read: 90100
# Number of files read: 90200
# Number of files read: 90300
# Number of files read: 90400
# Number of files read: 90500
# Number of files read: 90600
# Number of files read: 90700
# Number of files read: 90800
# Number of files read: 90900
# Number of files read: 91000
# Number of files read: 91100
# Number of files read: 91200
# Number of files read: 91300
# Number of files read: 91400
# Number of files read: 91500
# Number of files read: 91600
# Number of files read: 91700
# Number of files read: 91800
# Number of files read: 91900
# Number of files read: 92000
# Number of files read: 120800
# Number of files read: 120900
# Number of files read: 121000
# Number of files read: 121100
# Number of files read: 121200
# Number of files read: 121300
# Number of files read: 121400
# Number of files read: 121500
# Number of files read: 121600
# Number of files read: 121700
# Number of files read: 121800
# Number of files read: 121900
# Number of files read: 122000
# Number of files read: 122100
# Number of files read: 122200
# Number of files read: 122300
# Number of files read: 122400
# Number of files read: 122500
# Number of files read: 122600
# Number of files read: 122700
# Number of files read: 122800
# Number of files read: 122900
# Number of files read: 123000
# Number of files read: 123100
# Number of files read: 123200
# Number of files read: 123300
# Number of files read: 123400
# Number of files read: 123500
# Number of files read: 123600
# Number of files read: 123700
# Number of files read: 123800
# Number of files read: 123900
# Number of files read: 124000
# Number of files read: 124100
# Number of files read: 124200
# Number of files read: 124300
# Number of files read: 124400
# Number of files read: 124500
# Number of files read: 124600
# Number of files read: 124700
# Number of files read: 124800
# Number of files read: 124900
# Number of files read: 125000
# Number of files read: 125100
# Number of files read: 125200
# Number of files read: 125300
# Number of files read: 125400
# Number of files read: 125500
# Number of files read: 125600
# Number of files read: 125700
# Number of files read: 125800
# Number of files read: 125900
# Number of files read: 126000
# Number of files read: 126100
# Number of files read: 126200
# Number of files read: 126300
# Number of files read: 126400
# Number of files read: 126500
# Number of files read: 126600
# Number of files read: 126700
# Number of files read: 126800
# Number of files read: 126900
# Number of files read: 127000
# Number of files read: 127100
# Number of files read: 127200
# Number of files read: 127300
# Number of files read: 127400
# Number of files read: 127500
# Number of files read: 127600
# Number of files read: 127700
# Number of files read: 127800
# Number of files read: 127900
# Number of files read: 128000
# Number of files read: 128100
# Number of files read: 128200
# Number of files read: 128300
# Number of files read: 128400
# Number of files read: 128500
# Number of files read: 128600
# Number of files read: 128700
# Number of files read: 128800
# Number of files read: 128900
# Number of files read: 129000
# Number of files read: 129100
# Number of files read: 129200
# Number of files read: 129300
# Number of files read: 129400
# Number of files read: 129500
# Number of files read: 129600
# Number of files read: 129700
# Number of files read: 129800
# Number of files read: 129900
# Number of rows added: 619229

# %%
concat_text_trunc_df = pd.DataFrame.from_dict(covid19_dict,orient='index')
concat_text_trunc_df
# Out:
#         cord_uid                                           sentence  \
# 0       o81b9htu  How do we protect our 'high-risk' patient popu...
# 1       o81b9htu  A hospital-wide high-risk patient working grou...
# 2       o81b9htu  The inclusion of immunocompromised patients in...
# 3       o81b9htu  With the current outbreak, reports of 2 heart ...
# 4       o81b9htu  Not only has evidence that immunosuppression c...
# ...          ...                                                ...
# 619224  kuvfdl4q  In addition to the known pulmonary findings, i...
# 619225  kuvfdl4q  When the kidneys fail, hemodialysis offers a l...
# 619226  kuvfdl4q  The COVID-19 global emergency is making humans...
# 619227  kuvfdl4q  To address such a complex challenge, cooperati...
# 619228  kuvfdl4q  In this view, nanotechnology is inherently a f...
#
#                                                   section
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 619224  Two-Dimensional Carbides and Nitrides (MXenes)...
# 619225  Two-Dimensional Carbides and Nitrides (MXenes)...
# 619226  Rethinking the Future: One Health, Contaminati...
# 619227  Rethinking the Future: One Health, Contaminati...
# 619228  Rethinking the Future: One Health, Contaminati...
#
# [619229 rows x 3 columns]

# %%
concat_text_trunc_df.to_json(full_text_df_outfile_path)

# %%
print('Number of papers extracted:',len(concat_text_trunc_df.cord_uid.unique()))
# Out:
# Number of papers extracted: 19883

# %%
"""
Functions to generate regex match patterns from synonymous words/phrases for filtering subject headers
"""

import re

def extract_regex_pattern(section_list, pattern):
    r = re.compile(pattern, re.IGNORECASE)
    extracted_list = list(filter(r.match, section_list))
    remaining_list = list(set(section_list) - set(extracted_list))
    
    return remaining_list, extracted_list

def construct_regex_match_pattern(terms_dict):
    fuzzy_terms = ['.*%s.*' % i for i in terms_dict['fuzzy']]
    exact_terms = terms_dict['exact']
    
    fuzzy_pattern = '|'.join(fuzzy_terms)
    #exact_pattern = '|'.join(exact_terms)
    
    full_pattern = fuzzy_pattern
    
    return full_pattern

# %%
"""
Extract putative discussion headers.
"""

#Construct regex pattern for discussion header terms and extract list of matching headers.

disc_terms_dict = {
    'exact': [],
    'fuzzy' : [
        'conclusion',
        'discussion',
        'interpretation',
        'added value of this study',
        'research in context',
        'concluding',
        'closing remarks',
        'summary of findings',
        'outcome'
    ]
}
conc_pattern = construct_regex_match_pattern(disc_terms_dict)
print(conc_pattern)
# Out:
# .*conclusion.*|.*discussion.*|.*interpretation.*|.*added value of this study.*|.*research in context.*|.*concluding.*|.*closing remarks.*|.*summary of findings.*|.*outcome.*

# %%
import pprint

#unique_sections = set(merged_text_vec_df.section.tolist())
unique_sections = set(concat_text_trunc_df.section.tolist())

rem_header_list, ext_header_list = extract_regex_pattern(unique_sections, conc_pattern)

print("Number of discussion headers: %d" % len(ext_header_list))
print("Example discussion headers:")
pprint.pprint(ext_header_list[:20])
# Out:
# Number of discussion headers: 3912
# Example discussion headers:
# ['IV -Discussion',
#  'Additional considerations for large-scale manufacturing and dissemination '
#  '::: Discussion',
#  'Discussion of case reports',
#  'Food purchase and preparation behaviors and attitudes toward COVID-19 '
#  'lockdown ::: Results and discussion',
#  'Survival ::: DISCUSSION',
#  'Clinical characteristics and outcomes of COVID-19 stratified by the number '
#  'of comorbidities',
#  'Determining the utility of LFAs for SARS-CoV-2 antibody detection 2.1 Visual '
#  'interpretation of LFA testing results',
#  'MS/MS Data Interpretation and label free protein quantification',
#  'Considerations of dosing regimen for special population ::: Discussion',
#  '5. Discussion',
#  'Limitations and conclusion',
#  'IV. CONCLUSIONS:',
#  'Limitation ::: Discussions',
#  '3.3.9. Republic of Congo ::: 3.3. Central Africa ::: 3. Results and '
#  'Discussion',
#  'Experimental Protocols, Classification Results and Discussion',
#  'Clinical Characteristics and Outcomes ::: Results',
#  'Primary outcome: psychological and mental impacts',
#  'Scholars and institutions ::: Discussion',
#  'Lipid Membrane Rigidity ::: Results and Discussion',
#  'A.1.2 Theoretical analysis on interpretation of exponents']

# %%
#For now, lower-casing all section headers for matching

section_exact_match_list = set([i.lower() for i in ext_header_list])
section_exact_match_list.add('abstract')
section_exact_match_list.add('title')

print("Number of sections filtering to: %d" % len(section_exact_match_list))
# Out:
# Number of sections filtering to: 3635

# %%
print('Step 3: Filtering to title, abstract and discussion sections...')
merged_df_filtered_to_sections_oi = concat_text_trunc_df.loc[concat_text_trunc_df.section.str.lower().isin(section_exact_match_list)]

merged_df_filtered_to_sections_oi.to_csv(filt_text_df_outfile_path, index=False)

# %%
print('Number of papers after filtering to sections:',len(merged_df_filtered_to_sections_oi.cord_uid.unique()))
# Out:
# Number of papers after filtering to sections: 13465

# %%
"""
Filtering out sentences with less than three non-header words.

Author: Malavika Suresh

"""
input_data = merged_df_filtered_to_sections_oi

# %%
#Keep only sentences containing at least 3 words other than those defined below
#This also removes any sentences that do not contain any words at all

print('Step 4: Filtering our noisy sentences...')
rep = {"text": "", "cite_spans": "", "ref_spans": "", "section": "", "Abstract": "",\
       "bioRxiv preprint": "", "medRxiv preprint": "", "doi:": ""}
rep = dict((re.escape(k), v) for k, v in rep.items())
pattern = re.compile("|".join(rep.keys()))
sentences_temp = [pattern.sub(lambda m: rep[re.escape(m.group(0))], s) for s in input_data.sentence]
pattern = re.compile(".*[A-Za-z].*")
sentences_to_keep = [(bool(re.search(pattern,s))) & (len(s.split(' '))>2) for s in sentences_temp]
input_processed = input_data.loc[sentences_to_keep,:]
sentences_to_drop = [not i for i in sentences_to_keep]
input_excluded = input_data.loc[sentences_to_drop,:]

# %%
print('Number of papers after filtering sentences:',len(input_processed.cord_uid.unique()))
# Out:
# Number of papers after filtering sentences: 13390

# %%
input_processed.to_csv(processed_text_df_outfile_path)
# input_excluded.to_csv('%scord_titles_abstracts_conclusions_excluded.csv' % output_path)

# %%
input_processed
# Out:
#         cord_uid                                           sentence  \
# 17      dwrazfli  The crisis generated by the COVID-19 pandemic ...
# 22      5k0ktboh  Asymptomatic and atypical presentations of COV...
# 23      5k0ktboh  The patient's radiological findings were enoug...
# 24      5k0ktboh  The atypical presentation and lack of communic...
# 25      5k0ktboh  Asymptomatic and atypical presentations of COV...
# ...          ...                                                ...
# 619135  pgluidj8  The CT values of both ORF1ab and N\ngenes betw...
# 619136  pgluidj8  A total of 181 samples (patients) were tested....
# 619137  pgluidj8  Nevertheless, as the clinical information on t...
# 619138  pgluidj8  The distinctive features of high sensitivity, ...
# 619139  pgluidj8  Collectively, the OSN-qRT-PCR assay has advant...
#
#                                                   section
# 17                                            Conclusions
# 22                                             Discussion
# 23                                             Discussion
# 24                                             Discussion
# 25                                             Conclusion
# ...                                                   ...
# 619135       CT Value Analysis ::: Results and Discussion
# 619136  Characterization of the Samples ::: Results an...
# 619137  Characterization of the Samples ::: Results an...
# 619138        Applicable Scene ::: Results and Discussion
# 619139                                         Conclusion
#
# [84267 rows x 3 columns]

# %%
title_data = input_processed.loc[input_processed.section.str.lower()=='title',:]
abstract_data = input_processed.loc[input_processed.section.str.lower()=='abstract',:]
conclusion_data = input_processed.loc[(input_processed.section.str.lower()!='title') & (input_processed.section.str.lower()!='abstract'),:]

# %%
print('Number of papers:', input_processed.cord_uid.nunique())
print('Number of papers with title:', title_data.cord_uid.nunique())
print('Number of papers with abstract:', abstract_data.cord_uid.nunique())
print('Number of papers with conclusion:', conclusion_data.cord_uid.nunique())
# Out:
# Number of papers: 13390
# Number of papers with title: 2
# Number of papers with abstract: 10539
# Number of papers with conclusion: 10408
